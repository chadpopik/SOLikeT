# %%
import os,sys
import numpy as np
import matplotlib.pyplot as plt

homepath = "/global/homes/c/cpopik/"
packpath = homepath+"Packages/"
resultspath = homepath+"Results/NaWrapper/"

soliket_path = packpath+"SOLiket/"
soliket_2_path = packpath+"SOLiket/soliket/"
soliket_test_path = packpath+"SOLiket/soliket/tests/"
soliket_xcorr_path = packpath+"SOLiket/soliket/xcorr/"

soliketcobaya_path = packpath+"SOLikeT_cobaya/"

# %%
sys.path.append(soliket_test_path)
from soliket.xcorr import XcorrLikelihood  # noqa: F401
from soliket.szlike import szlike  # noqa: F401

# %%
szlike.TSZLikelihood
# Out:
# soliket.szlike.szlike.TSZLikelihood

# %%
sz_data_file: /global/homes/c/cpopik/Packages/SOLikeT/soliket/szlike/gnfw_test_projections.txt
beam_file: /global/homes/c/cpopik/Packages/SOLikeT/soliket/szlike/beam_f150_daynight.txt
transform_type: Hankel
beam_response: /global/homes/c/cpopik/Packages/SOLikeT/soliket/szlike/act_planck_s08_s18_cmb_f150_daynight_response_tsz.txt
cov_tsz_file: /global/homes/c/cpopik/Packages/SOLikeT/soliket/szlike/cov_diskring_tsz_varweight_bootstrap.txt
twohalo_term: /global/homes/c/cpopik/Packages/SOLikeT/soliket/szlike/twohalo_cmass_average.txt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [8], line 1
# ----> 1 Optional
#
# NameError: name 'Optional' is not defined

# %%
thta_arc, tsz_data = np.loadtxt("/global/homes/c/cpopik/Packages/SOLikeT/soliket/szlike/gnfw_test_projections.txt", usecols=(0, 4), unpack=True)
tsz_data /= 3282.8 * 60.0**2  # units muK*sr

# %%
plt.plot(tsz_data)
plt.show()

# %%
tsz_data
# Out:
# array([-0.78847399, -1.90965567, -2.80261072, -3.60904461, -4.39734938,
#        -5.23814311, -6.16030747, -7.1846874 , -8.31319174])

# %%
thta_arc
# Out:
# array([1.   , 1.625, 2.25 , 2.875, 3.5  , 4.125, 4.75 , 5.375, 6.   ])

# %%
plt.axvline(20)
plt.show()
